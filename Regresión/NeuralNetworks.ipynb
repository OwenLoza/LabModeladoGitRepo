# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Sara Eugenia Rodríguez </Strong>
# - <Strong> Año </Strong>: 2025
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# Las redes neuronales profundas (deep learning) han ganado mucha popularidad en los últimos años, especialmente para problemas complejos, como el reconocimiento de imágenes, el procesamiento del lenguaje natural y otras aplicaciones que requieren modelos potentes.
#
# Sin embargo, las redes neuronales básicas también pueden usarse en problemas de aprendizaje supervisado más simples, como regresión o clasificación, AUNQUE hay varias razones por las cuales otros algoritmos son más comunes en estos casos...
#
# 1. Complejidad computacional
# 2. Sobreajuste (Overfitting)
# 3. Necesidad de más datos
# 4. Tuning de Hiperparámetros (las redes neuronales tienen muchos hiperparámetros)
# 5. Interpretabilidad, son modelos de caja negra
#
# **¿Cuándo se utilizan redes neuronales en aprendizaje supervisado?**
#
# Aunque no siempre son la primera opción para problemas simples, las redes neuronales pueden ser muy útiles en problemas supervisados más complejos donde:
#
# - Hay gran cantidad de datos disponibles
# - Los problemas son no lineales
# - Hay tareas de percepción involucradas (como visión por computadora, reconocimiento de voz o procesamiento de lenguaje natural), donde las redes neuronales profundas sobresalen.

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %% [markdown]
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - RELU: es la más utilizada para capas ocultas. Es fácil de calcular, lo que la hace más rápida para entrenar. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Leaky RELU: Similar a ReLU, pero permite valores negativos pequeños cuando x≤0, lo que evita que las neuronas queden completamente inactivas.
# - Evita Sigmoid y Tanh en las capas ocultas
#
# **¿Cómo elegir la función de activación para las capas de salida?**
#
# - Lineal: Para problemas de regresión donde la salida es un valor continuo.
# - Sigmoidal: típicamente para problemas de clasificación binaria.
# - Softmax: Para problemas de clasificación multiclase
#
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# - Problemas sencillos: Una sola capa oculta suele ser suficiente para capturar patrones simples.
# - Problemas más complejos (con relaciones no lineales más complicadas): Dos capas ocultas pueden ser útiles
#
# En la práctica, la mayoría de los problemas sencillos no necesitan más de 1 o 2 capas ocultas.
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# - Un buen punto de partida es comenzar con un número de neuronas que sea similar o cercano al número de características de entrada.
# - Para problemas simples, puedes comenzar con entre 4 y 16 neuronas por capa.
# - Si los datos tienen una cantidad moderada de complejidad o son no lineales, podrías aumentar a 32 o 64 neuronas en la capa oculta.
# - Evita tener muchas más neuronas que características de entrada, ya que eso puede llevar a un sobreajuste.
# - En redes con múltiples capas ocultas, una estrategia común es que las capas posteriores tengan menos neuronas que las capas iniciales. Esto es porque las primeras capas extraen más características, mientras que las capas más profundas se enfocan en combinarlas.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas
#
#
# **¿Por qué el deep learning no funciona tan bien en problemas clásicos de regresión/clasificación?**
#
# Gran parte del éxito de las redes neuronales modernas proviene de su capacidad para explotar la naturaleza compositiva del mundo. Es decir, en problemas de percepción como el análisis de imágenes o audio, las características tienen un orden (espacial o temporal) y los patrones locales se agregan para formar conceptos y objetos de nivel superior (por ejemplo, la imagen de un automóvil está hecha de ruedas y otras partes, que están hechas de características visuales de nivel inferior, que están hechas de formas básicas como bordes, círculos y líneas, etc.).
#
# Las redes neuronales modernas, como las redes neuronales convolucionales (CNN), aprovechan esto aprendiendo características cada vez más abstractas en las capas más profundas.
#
# Por el contrario, los problemas de regresión clásicos constan de una serie de características no ordenadas, y el valor objetivo se puede predecir bastante bien con un modelo lineal/no lineal superficial de las características de entrada. En cierto sentido, esta propiedad composicional presente en problemas como la clasificación de imágenes o el reconocimiento de voz no está presente en problemas como "Predecir los ingresos de un individuo en función de su sexo, edad, nacionalidad, grado académico, tamaño de la familia...".

# %% [markdown]
# ## Ejemplo: Eficiencia de Energia
#
# Se busca analizar la eficiencia energética de los edificios.
#
# Se realizaron análisis energéticos utilizando 12 tipos de edificios diferentes simulados en Ecotect.
#
# Los edificios se diferencian en cuanto a la superficie con cristales, la distribución del área acristalada y la orientación, entre otros parámetros.
#
# Se simularon varios escenarios en función de las características antes mencionadas para obtener 768 formas de edificios.
#
# El conjunto de datos comprende 768 muestras y 8 características, con el objetivo de predecir dos respuestas con valor real.
#
# Información de atributos:
# - X1 Relative Compactness
# - X2 Surface Area
# - X3 Wall Area
# - X4 Roof Area
# - X5 Overall Height
# - X6 Orientation
# - X7 Glazing Area
# - X8 Glazing Area Distribution
#
# Targets:
# - Y1: Heating Load (in Wh)
# - Y2: Cooling Load (in Wh)
# -
# Las características son numéricas y representan diversas características físicas del edificio, mientras que las variables objetivo representan la energía necesaria para calefacción y enfriamiento.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ENB2012_data.csv")

df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# 25%      0.100000    1.75000   12.992500   15.620000
# 50%      0.250000    3.00000   18.950000   22.080000
# 75%      0.400000    4.00000   31.667500   33.132500
# max      0.400000    5.00000   43.100000   48.030000

# %%
#Matriz de correlaciones
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
#Correlaciones con el target
correlation_target = df.corr()[['Y1','Y2']]
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_target, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Target')
plt.show()

# %%
#Distribucion de las varialbes
sns.pairplot(df)

# %% [markdown]
# ### Modelado

# %% [markdown]
# Vamos a usar una red compartida con dos salidas (cooling and heating load), ya que los dos targets están físicamente relacionados y la red puede aprender representaciones compartidas.
#
# Algunos tips para empezar la arquitectura inicial de la red:
#
# **a. Entrada y salida**
#
# - Entradas: 8 características → tamaño de capa de entrada = 8
# - Salidas: 2 objetivos → tamaño de capa de salida = 2
#
# **b. Capas ocultas**
#
# Por lo general, comienzas poco a poco y vas ampliando:
#
# - Comienza con 1 a 2 capas ocultas.
# - Numero de neuronas: entre el tamaño de entrada y salida (8) y tal vez entre 2 y 4 veces más (16–32–64).
#
# Por ejemplo:
# Input (8)
# ↓
# Dense(64, ReLU)
# ↓
# Dense(32, ReLU)
# ↓
# Dense(2, Linear)
#
# **c. Funcion de activacion**
#
# Comenzar con RELU para capas ocultas
#
# **d. Agregar Regularizacion**
#
# Agregar regularizacion si vemos overfitting (dropout)
#
# **e. Funcion de costo**
#
# MSE
#
# **f. Optimizer**
#
# Adam

# %%
X = df[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8']].values
y1 = df['Y1'].values  # Heating Load
y2 = df['Y2'].values  # Cooling Load

# %%
X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(X, y1, y2, test_size=0.2, random_state=42)

# %%
# Estandarizamos los datos
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Modelo Baseline

# %%
# Capa de entrada (8 variables)
input_layer = Input(shape=(X_train.shape[1],), name='input_layer')

# Capas ocultas compartidas
layer_dense1_shared=Dense(64 , activation='relu', name='shared_dense_1')(input_layer)
layer_dense2_shared=Dense(32,activation='relu',name='shared_dense_2')(layer_dense1_shared)
layer_dropout1_shared=Dropout(0.2,name='shared_dropout_1')(layer_dense2_shared)

#Estructura para Y1 (Heating Load)
y1_dense_1=Dense(32, activation='relu',name='y1_dense_1')(layer_dropout1_shared)
y1_dropout = Dropout(0.2, name='y1_dropout')(y1_dense_1)
y1_dense2 = Dense(16, activation='relu', name='y1_dense_2')(y1_dropout)
y1_output = Dense(1, name='y1_output')(y1_dense2)

#Estructura para Y2 (Cooling Load)
y2_dense1 = Dense(32, activation='relu', name='y2_dense_1')(layer_dropout1_shared)
y2_dropout = Dropout(0.2, name='y2_dropout')(y2_dense1)
y2_dense3 = Dense(16, activation='relu', name='y2_dense_3')(y2_dropout)
y2_output = Dense(1, name='y2_output')(y2_dense3)

# %%
#  Modelo que contenga la capa de entrada y las capas de salida 
model=Model(inputs=input_layer  ,outputs=[y1_output , y2_output])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_1      │ (None, 64)        │        576 │ input_layer[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_2      │ (None, 32)        │      2,080 │ shared_dense_1[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dropout_1    │ (None, 32)        │          0 │ shared_dense_2[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dropout          │ (None, 32)        │          0 │ y1_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dropout          │ (None, 32)        │          0 │ y2_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_2 (Dense)  │ (None, 16)        │        528 │ y1_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_3 (Dense)  │ (None, 16)        │        528 │ y2_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_output (Dense)   │ (None, 1)         │         17 │ y1_dense_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_output (Dense)   │ (None, 1)         │         17 │ y2_dense_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,858 (22.88 KB)
#  Trainable params: 5,858 (22.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilamos el modelo

model.compile(optimizer='adam', 
              loss={'y1_output': 'mse', 'y2_output': 'mse'}, 
              metrics={'y1_output': 'mae', 'y2_output': 'mae'})

# Entrenamos el modelo
history = model.fit(X_train, [y1_train, y2_train], epochs=200, batch_size=32, 
                    validation_data=(X_test, [y1_test, y2_test]))
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 1286.6398 - y1_output_loss: 589.9484 - y1_output_mae: 22.2150 - y2_output_loss: 685.8456 - y2_output_mae: 24.5521 - val_loss: 1333.7124 - val_y1_output_loss: 616.9841 - val_y1_output_mae: 22.5485 - val_y2_output_loss: 727.2990 - val_y2_output_mae: 25.0970
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1228.7803 - y1_output_loss: 568.3105 - y1_output_mae: 21.5178 - y2_output_loss: 668.4420 - y2_output_mae: 23.9939 - val_loss: 1252.2280 - val_y1_output_loss: 572.7885 - val_y1_output_mae: 21.5288 - val_y2_output_loss: 689.7889 - val_y2_output_mae: 24.3515
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1087.3018 - y1_output_loss: 484.8889 - y1_output_mae: 19.6603 - y2_output_loss: 588.8713 - y2_output_mae: 22.5144 - val_loss: 980.5711 - val_y1_output_loss: 437.5212 - val_y1_output_mae: 18.0954 - val_y2_output_loss: 552.3095 - val_y2_output_mae: 21.3622
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 690.6910 - y1_output_loss: 299.5579 - y1_output_mae: 14.2237 - y2_output_loss: 381.4429 - y2_output_mae: 16.9718 - val_loss: 370.6748 - val_y1_output_loss: 164.1462 - val_y1_output_mae: 9.7704 - val_y2_output_loss: 211.2577 - val_y2_output_mae: 11.3883
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 210.7537 - y1_output_loss: 101.9673 - y1_output_mae: 7.8380 - y2_output_loss: 107.9863 - y2_output_mae: 7.9805 - val_loss: 84.2539 - val_y1_output_loss: 43.3892 - val_y1_output_mae: 5.2021 - val_y2_output_loss: 41.9342 - val_y2_output_mae: 4.6955
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 111.7196 - y1_output_loss: 52.8392 - y1_output_mae: 5.5323 - y2_output_loss: 55.5974 - y2_output_mae: 5.5260 - val_loss: 68.2366 - val_y1_output_loss: 31.4225 - val_y1_output_mae: 4.0102 - val_y2_output_loss: 37.8188 - val_y2_output_mae: 4.7099
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 97.2128 - y1_output_loss: 44.4449 - y1_output_mae: 4.9101 - y2_output_loss: 50.1036 - y2_output_mae: 5.3443 - val_loss: 52.1197 - val_y1_output_loss: 24.9795 - val_y1_output_mae: 3.4448 - val_y2_output_loss: 27.6844 - val_y2_output_mae: 3.7951
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 85.0636 - y1_output_loss: 41.5718 - y1_output_mae: 4.7118 - y2_output_loss: 42.9384 - y2_output_mae: 4.9373 - val_loss: 46.5581 - val_y1_output_loss: 21.8569 - val_y1_output_mae: 3.1834 - val_y2_output_loss: 25.0625 - val_y2_output_mae: 3.6115
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 80.8877 - y1_output_loss: 41.1874 - y1_output_mae: 4.7772 - y2_output_loss: 38.7888 - y2_output_mae: 4.8007 - val_loss: 45.0243 - val_y1_output_loss: 20.6860 - val_y1_output_mae: 3.1259 - val_y2_output_loss: 24.6041 - val_y2_output_mae: 3.6839
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 75.8466 - y1_output_loss: 33.8907 - y1_output_mae: 4.3448 - y2_output_loss: 42.0953 - y2_output_mae: 4.7799 - val_loss: 41.4817 - val_y1_output_loss: 19.3298 - val_y1_output_mae: 2.9497 - val_y2_output_loss: 22.3774 - val_y2_output_mae: 3.3672
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 81.1525 - y1_output_loss: 36.1454 - y1_output_mae: 4.4192 - y2_output_loss: 43.2219 - y2_output_mae: 4.9762 - val_loss: 41.3093 - val_y1_output_loss: 19.0394 - val_y1_output_mae: 2.9277 - val_y2_output_loss: 22.5735 - val_y2_output_mae: 3.3117
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 71.5185 - y1_output_loss: 32.6679 - y1_output_mae: 4.1993 - y2_output_loss: 40.4245 - y2_output_mae: 4.7519 - val_loss: 36.7949 - val_y1_output_loss: 17.0402 - val_y1_output_mae: 2.8156 - val_y2_output_loss: 19.9744 - val_y2_output_mae: 3.1533
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 69.8403 - y1_output_loss: 29.9270 - y1_output_mae: 4.1503 - y2_output_loss: 38.2864 - y2_output_mae: 4.7141 - val_loss: 35.4720 - val_y1_output_loss: 15.9365 - val_y1_output_mae: 2.8113 - val_y2_output_loss: 19.6894 - val_y2_output_mae: 3.2122
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 66.7660 - y1_output_loss: 33.0154 - y1_output_mae: 4.0841 - y2_output_loss: 35.3076 - y2_output_mae: 4.4296 - val_loss: 33.1345 - val_y1_output_loss: 14.6823 - val_y1_output_mae: 2.7205 - val_y2_output_loss: 18.6510 - val_y2_output_mae: 2.9696
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 59.9802 - y1_output_loss: 26.0698 - y1_output_mae: 3.9171 - y2_output_loss: 32.2282 - y2_output_mae: 4.3140 - val_loss: 32.9661 - val_y1_output_loss: 15.2949 - val_y1_output_mae: 2.6852 - val_y2_output_loss: 17.8743 - val_y2_output_mae: 2.9327
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 62.4607 - y1_output_loss: 28.9029 - y1_output_mae: 4.1472 - y2_output_loss: 31.4906 - y2_output_mae: 4.2567 - val_loss: 30.4364 - val_y1_output_loss: 13.4462 - val_y1_output_mae: 2.5886 - val_y2_output_loss: 17.1637 - val_y2_output_mae: 2.8499
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 60.2614 - y1_output_loss: 28.4648 - y1_output_mae: 4.0545 - y2_output_loss: 32.5127 - y2_output_mae: 4.3014 - val_loss: 28.4888 - val_y1_output_loss: 12.9032 - val_y1_output_mae: 2.5350 - val_y2_output_loss: 15.7165 - val_y2_output_mae: 2.7627
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 56.0367 - y1_output_loss: 25.9315 - y1_output_mae: 3.7761 - y2_output_loss: 29.0602 - y2_output_mae: 4.2486 - val_loss: 32.3830 - val_y1_output_loss: 14.3912 - val_y1_output_mae: 2.6355 - val_y2_output_loss: 18.2118 - val_y2_output_mae: 2.8676
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 59.6484 - y1_output_loss: 25.8941 - y1_output_mae: 3.9105 - y2_output_loss: 31.8888 - y2_output_mae: 4.2719 - val_loss: 25.1445 - val_y1_output_loss: 11.9464 - val_y1_output_mae: 2.3971 - val_y2_output_loss: 13.3444 - val_y2_output_mae: 2.6189
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 56.4645 - y1_output_loss: 23.2422 - y1_output_mae: 3.7164 - y2_output_loss: 31.3670 - y2_output_mae: 4.2167 - val_loss: 28.7810 - val_y1_output_loss: 13.0242 - val_y1_output_mae: 2.5176 - val_y2_output_loss: 16.0051 - val_y2_output_mae: 2.6193
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 56.6888 - y1_output_loss: 24.9851 - y1_output_mae: 3.6885 - y2_output_loss: 30.5781 - y2_output_mae: 4.1594 - val_loss: 24.8886 - val_y1_output_loss: 11.6603 - val_y1_output_mae: 2.3725 - val_y2_output_loss: 13.3731 - val_y2_output_mae: 2.4682
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 58.1920 - y1_output_loss: 25.6327 - y1_output_mae: 3.8774 - y2_output_loss: 31.3482 - y2_output_mae: 4.1527 - val_loss: 23.9445 - val_y1_output_loss: 10.6508 - val_y1_output_mae: 2.2787 - val_y2_output_loss: 13.4202 - val_y2_output_mae: 2.4660
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 52.8455 - y1_output_loss: 24.6524 - y1_output_mae: 3.6894 - y2_output_loss: 28.1890 - y2_output_mae: 4.1301 - val_loss: 24.3417 - val_y1_output_loss: 11.2044 - val_y1_output_mae: 2.3328 - val_y2_output_loss: 13.3304 - val_y2_output_mae: 2.4229
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 49.8535 - y1_output_loss: 24.2478 - y1_output_mae: 3.6076 - y2_output_loss: 26.2048 - y2_output_mae: 3.8320 - val_loss: 21.1752 - val_y1_output_loss: 9.6901 - val_y1_output_mae: 2.1808 - val_y2_output_loss: 11.5659 - val_y2_output_mae: 2.3573
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 49.4395 - y1_output_loss: 23.4457 - y1_output_mae: 3.6149 - y2_output_loss: 24.6324 - y2_output_mae: 3.7204 - val_loss: 26.1864 - val_y1_output_loss: 13.3110 - val_y1_output_mae: 2.6562 - val_y2_output_loss: 13.0534 - val_y2_output_mae: 2.3917
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 47.2015 - y1_output_loss: 21.4948 - y1_output_mae: 3.4973 - y2_output_loss: 24.3209 - y2_output_mae: 3.7441 - val_loss: 20.8519 - val_y1_output_loss: 9.4222 - val_y1_output_mae: 2.2158 - val_y2_output_loss: 11.4774 - val_y2_output_mae: 2.4155
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 52.9077 - y1_output_loss: 23.4760 - y1_output_mae: 3.6794 - y2_output_loss: 28.1596 - y2_output_mae: 3.9667 - val_loss: 20.8777 - val_y1_output_loss: 9.5810 - val_y1_output_mae: 2.2106 - val_y2_output_loss: 11.3414 - val_y2_output_mae: 2.3631
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 51.1386 - y1_output_loss: 24.3188 - y1_output_mae: 3.7531 - y2_output_loss: 25.6652 - y2_output_mae: 3.8078 - val_loss: 22.6791 - val_y1_output_loss: 10.4039 - val_y1_output_mae: 2.3035 - val_y2_output_loss: 12.4273 - val_y2_output_mae: 2.3757
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 48.2667 - y1_output_loss: 23.3621 - y1_output_mae: 3.6089 - y2_output_loss: 25.2131 - y2_output_mae: 3.7356 - val_loss: 19.8450 - val_y1_output_loss: 9.1975 - val_y1_output_mae: 2.1503 - val_y2_output_loss: 10.7463 - val_y2_output_mae: 2.2870
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 49.0003 - y1_output_loss: 21.6859 - y1_output_mae: 3.5554 - y2_output_loss: 26.2195 - y2_output_mae: 3.8143 - val_loss: 24.3429 - val_y1_output_loss: 11.4329 - val_y1_output_mae: 2.4920 - val_y2_output_loss: 13.1444 - val_y2_output_mae: 2.4596
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 49.3395 - y1_output_loss: 22.9181 - y1_output_mae: 3.5424 - y2_output_loss: 25.5352 - y2_output_mae: 3.7859 - val_loss: 21.7647 - val_y1_output_loss: 9.9128 - val_y1_output_mae: 2.2777 - val_y2_output_loss: 11.9658 - val_y2_output_mae: 2.3544
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 51.2927 - y1_output_loss: 21.3591 - y1_output_mae: 3.4222 - y2_output_loss: 31.2733 - y2_output_mae: 3.9954 - val_loss: 19.6331 - val_y1_output_loss: 9.1733 - val_y1_output_mae: 2.1483 - val_y2_output_loss: 10.5626 - val_y2_output_mae: 2.2083
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 48.4604 - y1_output_loss: 23.3820 - y1_output_mae: 3.4429 - y2_output_loss: 26.3138 - y2_output_mae: 3.8203 - val_loss: 25.2080 - val_y1_output_loss: 10.8762 - val_y1_output_mae: 2.4202 - val_y2_output_loss: 14.4878 - val_y2_output_mae: 2.6856
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 41.9319 - y1_output_loss: 21.0275 - y1_output_mae: 3.3182 - y2_output_loss: 22.1709 - y2_output_mae: 3.5500 - val_loss: 21.7188 - val_y1_output_loss: 10.3559 - val_y1_output_mae: 2.3463 - val_y2_output_loss: 11.4866 - val_y2_output_mae: 2.3058
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 48.4380 - y1_output_loss: 20.4417 - y1_output_mae: 3.3200 - y2_output_loss: 27.1123 - y2_output_mae: 3.9484 - val_loss: 18.3531 - val_y1_output_loss: 8.4884 - val_y1_output_mae: 2.0744 - val_y2_output_loss: 9.9417 - val_y2_output_mae: 2.2647
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 45.6603 - y1_output_loss: 22.3819 - y1_output_mae: 3.4959 - y2_output_loss: 22.1676 - y2_output_mae: 3.6543 - val_loss: 19.1120 - val_y1_output_loss: 8.7809 - val_y1_output_mae: 2.0912 - val_y2_output_loss: 10.4215 - val_y2_output_mae: 2.1832
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 43.6803 - y1_output_loss: 18.6426 - y1_output_mae: 3.1740 - y2_output_loss: 24.3893 - y2_output_mae: 3.7196 - val_loss: 20.6574 - val_y1_output_loss: 9.7087 - val_y1_output_mae: 2.2496 - val_y2_output_loss: 11.0250 - val_y2_output_mae: 2.2205
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 46.0896 - y1_output_loss: 23.6388 - y1_output_mae: 3.3858 - y2_output_loss: 27.2333 - y2_output_mae: 3.7289 - val_loss: 20.1502 - val_y1_output_loss: 8.3401 - val_y1_output_mae: 2.0432 - val_y2_output_loss: 11.8988 - val_y2_output_mae: 2.3738
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 45.9119 - y1_output_loss: 23.1319 - y1_output_mae: 3.4478 - y2_output_loss: 24.3205 - y2_output_mae: 3.6677 - val_loss: 27.8218 - val_y1_output_loss: 13.7589 - val_y1_output_mae: 2.7591 - val_y2_output_loss: 14.2760 - val_y2_output_mae: 2.6158
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 45.4334 - y1_output_loss: 20.2407 - y1_output_mae: 3.3012 - y2_output_loss: 23.6454 - y2_output_mae: 3.6443 - val_loss: 17.8509 - val_y1_output_loss: 8.0565 - val_y1_output_mae: 1.9666 - val_y2_output_loss: 9.7647 - val_y2_output_mae: 2.1818
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 43.8271 - y1_output_loss: 20.8893 - y1_output_mae: 3.3937 - y2_output_loss: 21.6298 - y2_output_mae: 3.5197 - val_loss: 18.1056 - val_y1_output_loss: 8.7493 - val_y1_output_mae: 2.0915 - val_y2_output_loss: 9.3462 - val_y2_output_mae: 2.1078
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 39.7761 - y1_output_loss: 19.9539 - y1_output_mae: 3.2512 - y2_output_loss: 19.7550 - y2_output_mae: 3.2768 - val_loss: 17.2517 - val_y1_output_loss: 7.9706 - val_y1_output_mae: 2.0089 - val_y2_output_loss: 9.1983 - val_y2_output_mae: 2.2557
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 45.8726 - y1_output_loss: 20.1493 - y1_output_mae: 3.3470 - y2_output_loss: 24.3907 - y2_output_mae: 3.7045 - val_loss: 21.1346 - val_y1_output_loss: 8.6413 - val_y1_output_mae: 2.1486 - val_y2_output_loss: 12.5641 - val_y2_output_mae: 2.4831
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 42.7448 - y1_output_loss: 20.9069 - y1_output_mae: 3.3102 - y2_output_loss: 22.9052 - y2_output_mae: 3.5834 - val_loss: 20.9185 - val_y1_output_loss: 9.5190 - val_y1_output_mae: 2.2508 - val_y2_output_loss: 11.4810 - val_y2_output_mae: 2.3101
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 40.2401 - y1_output_loss: 17.2493 - y1_output_mae: 3.0729 - y2_output_loss: 22.2749 - y2_output_mae: 3.5551 - val_loss: 18.2778 - val_y1_output_loss: 8.2317 - val_y1_output_mae: 2.0540 - val_y2_output_loss: 10.0986 - val_y2_output_mae: 2.1477
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 39.2936 - y1_output_loss: 18.2784 - y1_output_mae: 3.1508 - y2_output_loss: 19.7900 - y2_output_mae: 3.3235 - val_loss: 18.4630 - val_y1_output_loss: 8.0439 - val_y1_output_mae: 2.0447 - val_y2_output_loss: 10.4704 - val_y2_output_mae: 2.1857
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 39.2456 - y1_output_loss: 17.8227 - y1_output_mae: 3.1055 - y2_output_loss: 21.1132 - y2_output_mae: 3.4849 - val_loss: 18.1578 - val_y1_output_loss: 7.8502 - val_y1_output_mae: 1.9810 - val_y2_output_loss: 10.3594 - val_y2_output_mae: 2.1607
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 42.6890 - y1_output_loss: 18.5754 - y1_output_mae: 3.1331 - y2_output_loss: 23.6193 - y2_output_mae: 3.6098 - val_loss: 16.6700 - val_y1_output_loss: 7.5229 - val_y1_output_mae: 1.9352 - val_y2_output_loss: 9.1404 - val_y2_output_mae: 2.0764
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 39.3717 - y1_output_loss: 19.0734 - y1_output_mae: 3.1919 - y2_output_loss: 21.7549 - y2_output_mae: 3.4025 - val_loss: 17.5352 - val_y1_output_loss: 7.8609 - val_y1_output_mae: 2.0430 - val_y2_output_loss: 9.7671 - val_y2_output_mae: 2.1015
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 40.7039 - y1_output_loss: 20.7960 - y1_output_mae: 3.2740 - y2_output_loss: 20.0742 - y2_output_mae: 3.3621 - val_loss: 18.7020 - val_y1_output_loss: 8.5145 - val_y1_output_mae: 2.1124 - val_y2_output_loss: 10.3482 - val_y2_output_mae: 2.1317
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 43.5339 - y1_output_loss: 19.5464 - y1_output_mae: 3.3264 - y2_output_loss: 22.9423 - y2_output_mae: 3.5938 - val_loss: 16.9868 - val_y1_output_loss: 7.3840 - val_y1_output_mae: 1.9314 - val_y2_output_loss: 9.6288 - val_y2_output_mae: 2.1824
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 36.4383 - y1_output_loss: 15.5473 - y1_output_mae: 2.9778 - y2_output_loss: 20.5960 - y2_output_mae: 3.4479 - val_loss: 21.2775 - val_y1_output_loss: 8.1187 - val_y1_output_mae: 2.1313 - val_y2_output_loss: 13.3452 - val_y2_output_mae: 2.5654
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 36.5079 - y1_output_loss: 18.1228 - y1_output_mae: 3.0743 - y2_output_loss: 19.8591 - y2_output_mae: 3.2517 - val_loss: 18.8846 - val_y1_output_loss: 7.8658 - val_y1_output_mae: 2.0837 - val_y2_output_loss: 11.1439 - val_y2_output_mae: 2.2831
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 39.5868 - y1_output_loss: 18.9045 - y1_output_mae: 3.1849 - y2_output_loss: 19.7544 - y2_output_mae: 3.4391 - val_loss: 14.9261 - val_y1_output_loss: 6.7711 - val_y1_output_mae: 1.8701 - val_y2_output_loss: 8.1777 - val_y2_output_mae: 2.0049
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 37.7980 - y1_output_loss: 18.3409 - y1_output_mae: 3.1898 - y2_output_loss: 20.2310 - y2_output_mae: 3.2769 - val_loss: 16.1614 - val_y1_output_loss: 6.7418 - val_y1_output_mae: 1.9457 - val_y2_output_loss: 9.4772 - val_y2_output_mae: 2.1153
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 36.1959 - y1_output_loss: 15.5835 - y1_output_mae: 2.9381 - y2_output_loss: 20.4073 - y2_output_mae: 3.4825 - val_loss: 16.0105 - val_y1_output_loss: 6.6108 - val_y1_output_mae: 1.8529 - val_y2_output_loss: 9.4389 - val_y2_output_mae: 2.0487
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 43.0225 - y1_output_loss: 19.4602 - y1_output_mae: 3.3240 - y2_output_loss: 22.4955 - y2_output_mae: 3.5700 - val_loss: 14.8820 - val_y1_output_loss: 6.6336 - val_y1_output_mae: 1.8685 - val_y2_output_loss: 8.2321 - val_y2_output_mae: 1.9863
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 37.3266 - y1_output_loss: 15.9082 - y1_output_mae: 2.9408 - y2_output_loss: 21.2307 - y2_output_mae: 3.3515 - val_loss: 19.5394 - val_y1_output_loss: 7.7072 - val_y1_output_mae: 2.1438 - val_y2_output_loss: 11.9884 - val_y2_output_mae: 2.4237
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 37.7326 - y1_output_loss: 16.4035 - y1_output_mae: 2.9905 - y2_output_loss: 20.9905 - y2_output_mae: 3.4735 - val_loss: 16.0415 - val_y1_output_loss: 6.8728 - val_y1_output_mae: 1.9145 - val_y2_output_loss: 9.2593 - val_y2_output_mae: 2.0457
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 32.5105 - y1_output_loss: 15.6770 - y1_output_mae: 2.9745 - y2_output_loss: 15.8949 - y2_output_mae: 3.0070 - val_loss: 15.4419 - val_y1_output_loss: 6.5370 - val_y1_output_mae: 1.8215 - val_y2_output_loss: 8.9214 - val_y2_output_mae: 2.0740
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 38.4620 - y1_output_loss: 16.3365 - y1_output_mae: 3.0108 - y2_output_loss: 21.4238 - y2_output_mae: 3.3994 - val_loss: 26.2574 - val_y1_output_loss: 11.0264 - val_y1_output_mae: 2.6505 - val_y2_output_loss: 15.4887 - val_y2_output_mae: 2.8940
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 41.6386 - y1_output_loss: 18.7460 - y1_output_mae: 3.1392 - y2_output_loss: 21.9407 - y2_output_mae: 3.4535 - val_loss: 19.8724 - val_y1_output_loss: 7.9626 - val_y1_output_mae: 2.2197 - val_y2_output_loss: 12.0980 - val_y2_output_mae: 2.4967
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 34.6782 - y1_output_loss: 16.0901 - y1_output_mae: 3.0235 - y2_output_loss: 17.7999 - y2_output_mae: 3.1758 - val_loss: 14.2504 - val_y1_output_loss: 6.4093 - val_y1_output_mae: 1.9217 - val_y2_output_loss: 7.8774 - val_y2_output_mae: 1.9781
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 35.2301 - y1_output_loss: 17.0107 - y1_output_mae: 2.9000 - y2_output_loss: 19.6816 - y2_output_mae: 3.3060 - val_loss: 15.3188 - val_y1_output_loss: 6.6192 - val_y1_output_mae: 1.9187 - val_y2_output_loss: 8.7837 - val_y2_output_mae: 1.9616
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 34.9304 - y1_output_loss: 16.0616 - y1_output_mae: 2.8882 - y2_output_loss: 19.0094 - y2_output_mae: 3.1651 - val_loss: 15.1760 - val_y1_output_loss: 6.9661 - val_y1_output_mae: 2.0048 - val_y2_output_loss: 8.2821 - val_y2_output_mae: 1.9338
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 36.6297 - y1_output_loss: 16.7233 - y1_output_mae: 3.0729 - y2_output_loss: 18.7664 - y2_output_mae: 3.2426 - val_loss: 15.0579 - val_y1_output_loss: 6.1233 - val_y1_output_mae: 1.7952 - val_y2_output_loss: 8.9706 - val_y2_output_mae: 2.0995
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 35.2631 - y1_output_loss: 15.8410 - y1_output_mae: 2.9155 - y2_output_loss: 19.5408 - y2_output_mae: 3.2704 - val_loss: 17.0378 - val_y1_output_loss: 7.8490 - val_y1_output_mae: 2.1799 - val_y2_output_loss: 9.2997 - val_y2_output_mae: 2.0929
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 33.9538 - y1_output_loss: 14.5892 - y1_output_mae: 2.8971 - y2_output_loss: 18.7526 - y2_output_mae: 3.3726 - val_loss: 13.7028 - val_y1_output_loss: 5.7855 - val_y1_output_mae: 1.7691 - val_y2_output_loss: 7.8866 - val_y2_output_mae: 1.9832
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 35.7832 - y1_output_loss: 16.6063 - y1_output_mae: 3.0057 - y2_output_loss: 19.0397 - y2_output_mae: 3.2318 - val_loss: 14.1919 - val_y1_output_loss: 6.1985 - val_y1_output_mae: 1.8687 - val_y2_output_loss: 8.0172 - val_y2_output_mae: 1.9165
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 32.8897 - y1_output_loss: 13.9912 - y1_output_mae: 2.8197 - y2_output_loss: 18.4871 - y2_output_mae: 3.2449 - val_loss: 14.4318 - val_y1_output_loss: 5.7059 - val_y1_output_mae: 1.7435 - val_y2_output_loss: 8.7796 - val_y2_output_mae: 1.9418
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 37.8298 - y1_output_loss: 18.2215 - y1_output_mae: 3.0603 - y2_output_loss: 19.7903 - y2_output_mae: 3.3090 - val_loss: 18.9363 - val_y1_output_loss: 7.6232 - val_y1_output_mae: 2.2105 - val_y2_output_loss: 11.5158 - val_y2_output_mae: 2.4129
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 30.5066 - y1_output_loss: 13.7728 - y1_output_mae: 2.7325 - y2_output_loss: 16.9936 - y2_output_mae: 3.0374 - val_loss: 18.4312 - val_y1_output_loss: 7.7834 - val_y1_output_mae: 2.1789 - val_y2_output_loss: 10.7832 - val_y2_output_mae: 2.2510
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 37.3225 - y1_output_loss: 18.0723 - y1_output_mae: 3.0077 - y2_output_loss: 19.8181 - y2_output_mae: 3.3507 - val_loss: 13.8506 - val_y1_output_loss: 6.0125 - val_y1_output_mae: 1.8323 - val_y2_output_loss: 7.8179 - val_y2_output_mae: 1.9455
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 36.1182 - y1_output_loss: 17.3191 - y1_output_mae: 3.1062 - y2_output_loss: 17.7347 - y2_output_mae: 3.1590 - val_loss: 14.2956 - val_y1_output_loss: 6.0377 - val_y1_output_mae: 1.9120 - val_y2_output_loss: 8.3060 - val_y2_output_mae: 2.0001
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 36.5119 - y1_output_loss: 16.7098 - y1_output_mae: 2.9278 - y2_output_loss: 18.8267 - y2_output_mae: 3.2210 - val_loss: 15.4356 - val_y1_output_loss: 6.4542 - val_y1_output_mae: 1.9761 - val_y2_output_loss: 9.0613 - val_y2_output_mae: 2.0511
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 33.6360 - y1_output_loss: 16.4920 - y1_output_mae: 2.9178 - y2_output_loss: 17.4295 - y2_output_mae: 3.1050 - val_loss: 13.3005 - val_y1_output_loss: 5.3650 - val_y1_output_mae: 1.7203 - val_y2_output_loss: 7.9500 - val_y2_output_mae: 1.9105
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 33.2621 - y1_output_loss: 15.9094 - y1_output_mae: 2.8490 - y2_output_loss: 17.4617 - y2_output_mae: 3.1818 - val_loss: 19.5939 - val_y1_output_loss: 7.3958 - val_y1_output_mae: 2.1404 - val_y2_output_loss: 12.4334 - val_y2_output_mae: 2.4966
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 34.9532 - y1_output_loss: 16.0625 - y1_output_mae: 3.0053 - y2_output_loss: 17.7704 - y2_output_mae: 3.2251 - val_loss: 17.3151 - val_y1_output_loss: 7.1417 - val_y1_output_mae: 2.1207 - val_y2_output_loss: 10.3120 - val_y2_output_mae: 2.2294
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 33.2055 - y1_output_loss: 14.3592 - y1_output_mae: 2.7937 - y2_output_loss: 18.8104 - y2_output_mae: 3.2796 - val_loss: 12.8995 - val_y1_output_loss: 5.3495 - val_y1_output_mae: 1.7353 - val_y2_output_loss: 7.5880 - val_y2_output_mae: 1.8872
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 33.9659 - y1_output_loss: 17.7033 - y1_output_mae: 3.0115 - y2_output_loss: 17.1146 - y2_output_mae: 3.0539 - val_loss: 13.3317 - val_y1_output_loss: 5.5133 - val_y1_output_mae: 1.7793 - val_y2_output_loss: 7.8689 - val_y2_output_mae: 1.9093
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 32.2997 - y1_output_loss: 13.9803 - y1_output_mae: 2.7984 - y2_output_loss: 18.5040 - y2_output_mae: 3.0987 - val_loss: 12.4708 - val_y1_output_loss: 5.2308 - val_y1_output_mae: 1.7091 - val_y2_output_loss: 7.2239 - val_y2_output_mae: 1.8702
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 35.3027 - y1_output_loss: 15.8581 - y1_output_mae: 2.9231 - y2_output_loss: 19.2660 - y2_output_mae: 3.2159 - val_loss: 16.7790 - val_y1_output_loss: 6.5601 - val_y1_output_mae: 2.0583 - val_y2_output_loss: 10.4121 - val_y2_output_mae: 2.2940
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 37.0421 - y1_output_loss: 16.7863 - y1_output_mae: 3.0695 - y2_output_loss: 20.1449 - y2_output_mae: 3.3424 - val_loss: 15.9500 - val_y1_output_loss: 6.1832 - val_y1_output_mae: 1.9334 - val_y2_output_loss: 9.8980 - val_y2_output_mae: 2.2072
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 34.1560 - y1_output_loss: 16.2970 - y1_output_mae: 2.9389 - y2_output_loss: 17.5364 - y2_output_mae: 3.1858 - val_loss: 13.2559 - val_y1_output_loss: 5.2980 - val_y1_output_mae: 1.7190 - val_y2_output_loss: 7.9576 - val_y2_output_mae: 1.9321
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 35.2217 - y1_output_loss: 16.0150 - y1_output_mae: 2.8291 - y2_output_loss: 19.5535 - y2_output_mae: 3.2192 - val_loss: 12.5173 - val_y1_output_loss: 5.1700 - val_y1_output_mae: 1.7232 - val_y2_output_loss: 7.3691 - val_y2_output_mae: 1.8735
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 34.5268 - y1_output_loss: 16.8460 - y1_output_mae: 2.9739 - y2_output_loss: 18.2183 - y2_output_mae: 3.1476 - val_loss: 13.8002 - val_y1_output_loss: 6.0393 - val_y1_output_mae: 1.9262 - val_y2_output_loss: 7.8415 - val_y2_output_mae: 1.9323
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 33.7597 - y1_output_loss: 15.4783 - y1_output_mae: 2.8953 - y2_output_loss: 17.8926 - y2_output_mae: 3.1908 - val_loss: 16.2283 - val_y1_output_loss: 5.8943 - val_y1_output_mae: 1.9159 - val_y2_output_loss: 10.4562 - val_y2_output_mae: 2.2730
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 35.0343 - y1_output_loss: 16.4892 - y1_output_mae: 2.8639 - y2_output_loss: 18.9626 - y2_output_mae: 3.2667 - val_loss: 12.2071 - val_y1_output_loss: 5.2568 - val_y1_output_mae: 1.6781 - val_y2_output_loss: 6.9389 - val_y2_output_mae: 1.8981
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 33.9171 - y1_output_loss: 16.9716 - y1_output_mae: 2.9700 - y2_output_loss: 17.1104 - y2_output_mae: 3.0253 - val_loss: 14.8584 - val_y1_output_loss: 6.8950 - val_y1_output_mae: 2.1066 - val_y2_output_loss: 8.0308 - val_y2_output_mae: 1.9452
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 33.1857 - y1_output_loss: 15.3763 - y1_output_mae: 2.8543 - y2_output_loss: 17.1266 - y2_output_mae: 3.1293 - val_loss: 13.3862 - val_y1_output_loss: 5.9623 - val_y1_output_mae: 1.9154 - val_y2_output_loss: 7.4720 - val_y2_output_mae: 1.9181
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 36.3002 - y1_output_loss: 16.0582 - y1_output_mae: 2.9965 - y2_output_loss: 19.2782 - y2_output_mae: 3.2785 - val_loss: 16.3157 - val_y1_output_loss: 7.0751 - val_y1_output_mae: 2.1558 - val_y2_output_loss: 9.4505 - val_y2_output_mae: 2.1421
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 33.4609 - y1_output_loss: 15.4675 - y1_output_mae: 2.7789 - y2_output_loss: 19.8681 - y2_output_mae: 3.1838 - val_loss: 17.4983 - val_y1_output_loss: 7.6303 - val_y1_output_mae: 2.2111 - val_y2_output_loss: 10.0117 - val_y2_output_mae: 2.1969
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 30.8239 - y1_output_loss: 13.7474 - y1_output_mae: 2.7919 - y2_output_loss: 17.3903 - y2_output_mae: 3.1039 - val_loss: 19.4810 - val_y1_output_loss: 7.6139 - val_y1_output_mae: 2.2381 - val_y2_output_loss: 12.1177 - val_y2_output_mae: 2.5305
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 31.1467 - y1_output_loss: 14.4493 - y1_output_mae: 2.8551 - y2_output_loss: 17.0525 - y2_output_mae: 3.0532 - val_loss: 16.8031 - val_y1_output_loss: 7.9361 - val_y1_output_mae: 2.2810 - val_y2_output_loss: 9.0210 - val_y2_output_mae: 2.0900
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 30.8133 - y1_output_loss: 13.7585 - y1_output_mae: 2.6988 - y2_output_loss: 16.8380 - y2_output_mae: 3.0787 - val_loss: 13.9210 - val_y1_output_loss: 5.5002 - val_y1_output_mae: 1.7687 - val_y2_output_loss: 8.5119 - val_y2_output_mae: 1.9824
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 31.9241 - y1_output_loss: 15.5566 - y1_output_mae: 2.8838 - y2_output_loss: 16.3470 - y2_output_mae: 3.0399 - val_loss: 13.3021 - val_y1_output_loss: 6.0448 - val_y1_output_mae: 1.9548 - val_y2_output_loss: 7.3510 - val_y2_output_mae: 1.8549
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 31.5748 - y1_output_loss: 15.7920 - y1_output_mae: 2.7578 - y2_output_loss: 16.9029 - y2_output_mae: 3.0153 - val_loss: 15.0251 - val_y1_output_loss: 5.0632 - val_y1_output_mae: 1.7175 - val_y2_output_loss: 10.0707 - val_y2_output_mae: 2.2812
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 28.8846 - y1_output_loss: 12.5335 - y1_output_mae: 2.6932 - y2_output_loss: 15.6646 - y2_output_mae: 3.0313 - val_loss: 14.3000 - val_y1_output_loss: 5.9586 - val_y1_output_mae: 1.9181 - val_y2_output_loss: 8.5124 - val_y2_output_mae: 2.0123
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 35.8232 - y1_output_loss: 16.5283 - y1_output_mae: 3.0628 - y2_output_loss: 18.6050 - y2_output_mae: 3.2998 - val_loss: 15.8260 - val_y1_output_loss: 6.2993 - val_y1_output_mae: 1.9839 - val_y2_output_loss: 9.7312 - val_y2_output_mae: 2.1730
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 33.4218 - y1_output_loss: 17.8491 - y1_output_mae: 2.9600 - y2_output_loss: 18.6097 - y2_output_mae: 3.0275 - val_loss: 11.9394 - val_y1_output_loss: 5.0639 - val_y1_output_mae: 1.7287 - val_y2_output_loss: 6.9192 - val_y2_output_mae: 1.7850
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 27.8071 - y1_output_loss: 13.0971 - y1_output_mae: 2.6896 - y2_output_loss: 14.4735 - y2_output_mae: 2.8464 - val_loss: 11.6823 - val_y1_output_loss: 4.8763 - val_y1_output_mae: 1.6557 - val_y2_output_loss: 6.8485 - val_y2_output_mae: 1.8740
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 31.7102 - y1_output_loss: 13.8936 - y1_output_mae: 2.7951 - y2_output_loss: 16.9053 - y2_output_mae: 3.0812 - val_loss: 12.1857 - val_y1_output_loss: 5.2242 - val_y1_output_mae: 1.7650 - val_y2_output_loss: 7.0357 - val_y2_output_mae: 1.8635
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 31.4816 - y1_output_loss: 14.4809 - y1_output_mae: 2.7697 - y2_output_loss: 18.5043 - y2_output_mae: 3.0019 - val_loss: 17.1672 - val_y1_output_loss: 7.0877 - val_y1_output_mae: 2.1511 - val_y2_output_loss: 10.2907 - val_y2_output_mae: 2.2685
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 30.6678 - y1_output_loss: 14.0047 - y1_output_mae: 2.8551 - y2_output_loss: 16.2293 - y2_output_mae: 3.0305 - val_loss: 12.2426 - val_y1_output_loss: 4.9211 - val_y1_output_mae: 1.6754 - val_y2_output_loss: 7.3925 - val_y2_output_mae: 1.8383
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 30.8109 - y1_output_loss: 14.8503 - y1_output_mae: 2.7499 - y2_output_loss: 16.3676 - y2_output_mae: 2.9476 - val_loss: 14.8984 - val_y1_output_loss: 5.6937 - val_y1_output_mae: 1.9112 - val_y2_output_loss: 9.3095 - val_y2_output_mae: 2.1522
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 28.3142 - y1_output_loss: 14.4216 - y1_output_mae: 2.7061 - y2_output_loss: 15.6488 - y2_output_mae: 2.8998 - val_loss: 15.2983 - val_y1_output_loss: 6.1215 - val_y1_output_mae: 1.9390 - val_y2_output_loss: 9.3530 - val_y2_output_mae: 2.1205
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 31.9309 - y1_output_loss: 14.5983 - y1_output_mae: 2.8814 - y2_output_loss: 16.4897 - y2_output_mae: 2.9881 - val_loss: 12.1557 - val_y1_output_loss: 4.9374 - val_y1_output_mae: 1.6731 - val_y2_output_loss: 7.2712 - val_y2_output_mae: 1.8189
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 29.3454 - y1_output_loss: 13.8857 - y1_output_mae: 2.7541 - y2_output_loss: 14.7628 - y2_output_mae: 2.8559 - val_loss: 13.2878 - val_y1_output_loss: 5.5381 - val_y1_output_mae: 1.8731 - val_y2_output_loss: 7.8572 - val_y2_output_mae: 1.9041
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 31.1139 - y1_output_loss: 14.6266 - y1_output_mae: 2.8429 - y2_output_loss: 15.5858 - y2_output_mae: 2.9372 - val_loss: 13.8662 - val_y1_output_loss: 5.6440 - val_y1_output_mae: 1.8581 - val_y2_output_loss: 8.3826 - val_y2_output_mae: 2.0019
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 29.8857 - y1_output_loss: 14.6169 - y1_output_mae: 2.7138 - y2_output_loss: 15.7278 - y2_output_mae: 2.9554 - val_loss: 11.0387 - val_y1_output_loss: 4.3470 - val_y1_output_mae: 1.5317 - val_y2_output_loss: 6.6678 - val_y2_output_mae: 1.7786
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 29.7070 - y1_output_loss: 15.1835 - y1_output_mae: 2.8148 - y2_output_loss: 14.2341 - y2_output_mae: 2.8635 - val_loss: 10.4872 - val_y1_output_loss: 4.3307 - val_y1_output_mae: 1.5742 - val_y2_output_loss: 6.1655 - val_y2_output_mae: 1.7385
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 28.8915 - y1_output_loss: 13.1881 - y1_output_mae: 2.6797 - y2_output_loss: 14.8701 - y2_output_mae: 2.9517 - val_loss: 14.6480 - val_y1_output_loss: 6.1371 - val_y1_output_mae: 1.9941 - val_y2_output_loss: 8.6990 - val_y2_output_mae: 2.0662
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 29.2077 - y1_output_loss: 12.8065 - y1_output_mae: 2.6436 - y2_output_loss: 15.7622 - y2_output_mae: 3.0184 - val_loss: 13.9872 - val_y1_output_loss: 5.6597 - val_y1_output_mae: 1.8849 - val_y2_output_loss: 8.4759 - val_y2_output_mae: 2.0176
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 28.7756 - y1_output_loss: 12.9590 - y1_output_mae: 2.5975 - y2_output_loss: 16.0634 - y2_output_mae: 2.8885 - val_loss: 17.7362 - val_y1_output_loss: 6.2819 - val_y1_output_mae: 1.9816 - val_y2_output_loss: 11.6561 - val_y2_output_mae: 2.4863
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 27.3015 - y1_output_loss: 11.2078 - y1_output_mae: 2.4932 - y2_output_loss: 15.7443 - y2_output_mae: 3.0101 - val_loss: 15.2419 - val_y1_output_loss: 6.0941 - val_y1_output_mae: 1.9742 - val_y2_output_loss: 9.3109 - val_y2_output_mae: 2.1259
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 28.8655 - y1_output_loss: 12.9549 - y1_output_mae: 2.6921 - y2_output_loss: 15.3268 - y2_output_mae: 2.9668 - val_loss: 13.4157 - val_y1_output_loss: 4.9803 - val_y1_output_mae: 1.7579 - val_y2_output_loss: 8.5698 - val_y2_output_mae: 2.0187
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 29.7367 - y1_output_loss: 13.4107 - y1_output_mae: 2.6340 - y2_output_loss: 15.4406 - y2_output_mae: 2.8974 - val_loss: 17.5527 - val_y1_output_loss: 8.0523 - val_y1_output_mae: 2.2838 - val_y2_output_loss: 9.7575 - val_y2_output_mae: 2.2044
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 33.9650 - y1_output_loss: 16.1008 - y1_output_mae: 2.8583 - y2_output_loss: 17.8984 - y2_output_mae: 3.1058 - val_loss: 12.2319 - val_y1_output_loss: 4.9551 - val_y1_output_mae: 1.7087 - val_y2_output_loss: 7.4132 - val_y2_output_mae: 1.8389
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 28.8696 - y1_output_loss: 13.7722 - y1_output_mae: 2.7110 - y2_output_loss: 15.3857 - y2_output_mae: 2.8662 - val_loss: 14.1369 - val_y1_output_loss: 6.9975 - val_y1_output_mae: 2.1936 - val_y2_output_loss: 7.2442 - val_y2_output_mae: 1.8311
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 27.3966 - y1_output_loss: 12.5052 - y1_output_mae: 2.6458 - y2_output_loss: 14.5662 - y2_output_mae: 2.8184 - val_loss: 11.7271 - val_y1_output_loss: 4.2323 - val_y1_output_mae: 1.5385 - val_y2_output_loss: 7.6088 - val_y2_output_mae: 1.8850
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 30.8694 - y1_output_loss: 15.3235 - y1_output_mae: 2.8546 - y2_output_loss: 15.8146 - y2_output_mae: 2.9222 - val_loss: 13.2877 - val_y1_output_loss: 5.6424 - val_y1_output_mae: 1.8648 - val_y2_output_loss: 7.7716 - val_y2_output_mae: 1.8824
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 28.7700 - y1_output_loss: 13.7725 - y1_output_mae: 2.6945 - y2_output_loss: 14.4781 - y2_output_mae: 2.8487 - val_loss: 14.0867 - val_y1_output_loss: 5.7375 - val_y1_output_mae: 1.9118 - val_y2_output_loss: 8.4888 - val_y2_output_mae: 2.0265
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 29.6480 - y1_output_loss: 12.9586 - y1_output_mae: 2.6202 - y2_output_loss: 16.2761 - y2_output_mae: 2.9071 - val_loss: 13.7066 - val_y1_output_loss: 5.7950 - val_y1_output_mae: 1.9324 - val_y2_output_loss: 8.1233 - val_y2_output_mae: 1.9992
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 28.7609 - y1_output_loss: 12.9452 - y1_output_mae: 2.6133 - y2_output_loss: 15.2195 - y2_output_mae: 2.8777 - val_loss: 14.9348 - val_y1_output_loss: 7.1247 - val_y1_output_mae: 2.1734 - val_y2_output_loss: 7.9961 - val_y2_output_mae: 1.9599
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 26.4700 - y1_output_loss: 12.1949 - y1_output_mae: 2.4859 - y2_output_loss: 13.9739 - y2_output_mae: 2.8278 - val_loss: 16.3498 - val_y1_output_loss: 6.8625 - val_y1_output_mae: 2.0872 - val_y2_output_loss: 9.7747 - val_y2_output_mae: 2.1887
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 28.0555 - y1_output_loss: 12.5634 - y1_output_mae: 2.6128 - y2_output_loss: 14.5528 - y2_output_mae: 2.8122 - val_loss: 11.5918 - val_y1_output_loss: 4.6504 - val_y1_output_mae: 1.6823 - val_y2_output_loss: 7.0684 - val_y2_output_mae: 1.8177
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 28.5612 - y1_output_loss: 13.7546 - y1_output_mae: 2.7104 - y2_output_loss: 14.8560 - y2_output_mae: 2.7871 - val_loss: 14.2168 - val_y1_output_loss: 5.3588 - val_y1_output_mae: 1.8063 - val_y2_output_loss: 9.0817 - val_y2_output_mae: 2.0827
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 26.9683 - y1_output_loss: 12.5794 - y1_output_mae: 2.4780 - y2_output_loss: 16.1384 - y2_output_mae: 2.8444 - val_loss: 16.2223 - val_y1_output_loss: 6.7806 - val_y1_output_mae: 2.1137 - val_y2_output_loss: 9.6840 - val_y2_output_mae: 2.2081
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 26.2202 - y1_output_loss: 12.2805 - y1_output_mae: 2.5651 - y2_output_loss: 13.2773 - y2_output_mae: 2.6808 - val_loss: 13.7793 - val_y1_output_loss: 6.0058 - val_y1_output_mae: 1.9486 - val_y2_output_loss: 8.0044 - val_y2_output_mae: 1.9441
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 27.5644 - y1_output_loss: 12.6331 - y1_output_mae: 2.5357 - y2_output_loss: 14.2107 - y2_output_mae: 2.7393 - val_loss: 11.5833 - val_y1_output_loss: 4.3134 - val_y1_output_mae: 1.5957 - val_y2_output_loss: 7.4153 - val_y2_output_mae: 1.8528
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 26.2122 - y1_output_loss: 12.4324 - y1_output_mae: 2.5655 - y2_output_loss: 13.3584 - y2_output_mae: 2.7356 - val_loss: 10.0922 - val_y1_output_loss: 4.5282 - val_y1_output_mae: 1.6170 - val_y2_output_loss: 5.6446 - val_y2_output_mae: 1.6356
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 28.5865 - y1_output_loss: 14.4433 - y1_output_mae: 2.7015 - y2_output_loss: 15.7985 - y2_output_mae: 2.8424 - val_loss: 9.4121 - val_y1_output_loss: 3.7625 - val_y1_output_mae: 1.3416 - val_y2_output_loss: 5.6249 - val_y2_output_mae: 1.8245
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 27.7199 - y1_output_loss: 11.5623 - y1_output_mae: 2.4668 - y2_output_loss: 16.6755 - y2_output_mae: 2.9936 - val_loss: 10.8136 - val_y1_output_loss: 4.5961 - val_y1_output_mae: 1.6462 - val_y2_output_loss: 6.2922 - val_y2_output_mae: 1.7195
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 27.1650 - y1_output_loss: 12.4008 - y1_output_mae: 2.5877 - y2_output_loss: 14.0896 - y2_output_mae: 2.7897 - val_loss: 12.1692 - val_y1_output_loss: 5.5322 - val_y1_output_mae: 1.8969 - val_y2_output_loss: 6.7672 - val_y2_output_mae: 1.8003
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.7191 - y1_output_loss: 11.1912 - y1_output_mae: 2.3849 - y2_output_loss: 12.9861 - y2_output_mae: 2.7405 - val_loss: 13.2605 - val_y1_output_loss: 5.6995 - val_y1_output_mae: 1.8877 - val_y2_output_loss: 7.7794 - val_y2_output_mae: 1.9167
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 24.2539 - y1_output_loss: 11.3985 - y1_output_mae: 2.4313 - y2_output_loss: 12.7942 - y2_output_mae: 2.5951 - val_loss: 13.7487 - val_y1_output_loss: 5.0337 - val_y1_output_mae: 1.7651 - val_y2_output_loss: 8.9771 - val_y2_output_mae: 2.1104
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 25.2429 - y1_output_loss: 11.5330 - y1_output_mae: 2.4006 - y2_output_loss: 13.3416 - y2_output_mae: 2.6786 - val_loss: 12.3400 - val_y1_output_loss: 5.5120 - val_y1_output_mae: 1.8698 - val_y2_output_loss: 6.9384 - val_y2_output_mae: 1.7996
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 26.4322 - y1_output_loss: 13.2187 - y1_output_mae: 2.5943 - y2_output_loss: 12.7713 - y2_output_mae: 2.6275 - val_loss: 13.7187 - val_y1_output_loss: 5.8118 - val_y1_output_mae: 1.8879 - val_y2_output_loss: 8.1441 - val_y2_output_mae: 1.9410
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 26.0266 - y1_output_loss: 10.5008 - y1_output_mae: 2.4079 - y2_output_loss: 15.5812 - y2_output_mae: 2.8528 - val_loss: 17.6562 - val_y1_output_loss: 7.1246 - val_y1_output_mae: 2.1843 - val_y2_output_loss: 10.7862 - val_y2_output_mae: 2.3910
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 25.1965 - y1_output_loss: 12.3070 - y1_output_mae: 2.4542 - y2_output_loss: 12.0827 - y2_output_mae: 2.5818 - val_loss: 19.5913 - val_y1_output_loss: 8.7119 - val_y1_output_mae: 2.3137 - val_y2_output_loss: 11.2602 - val_y2_output_mae: 2.4015
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 24.3349 - y1_output_loss: 12.5775 - y1_output_mae: 2.5513 - y2_output_loss: 12.4269 - y2_output_mae: 2.5963 - val_loss: 15.0098 - val_y1_output_loss: 5.5120 - val_y1_output_mae: 1.8839 - val_y2_output_loss: 9.7887 - val_y2_output_mae: 2.2186
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 24.7296 - y1_output_loss: 11.4276 - y1_output_mae: 2.4458 - y2_output_loss: 12.5514 - y2_output_mae: 2.6430 - val_loss: 9.6789 - val_y1_output_loss: 4.0581 - val_y1_output_mae: 1.6031 - val_y2_output_loss: 5.7466 - val_y2_output_mae: 1.6401
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 25.3801 - y1_output_loss: 11.4649 - y1_output_mae: 2.5041 - y2_output_loss: 13.2474 - y2_output_mae: 2.7225 - val_loss: 10.1606 - val_y1_output_loss: 4.2858 - val_y1_output_mae: 1.5996 - val_y2_output_loss: 6.0222 - val_y2_output_mae: 1.6806
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 25.0608 - y1_output_loss: 10.5584 - y1_output_mae: 2.4105 - y2_output_loss: 13.7642 - y2_output_mae: 2.7625 - val_loss: 9.4950 - val_y1_output_loss: 3.7807 - val_y1_output_mae: 1.5376 - val_y2_output_loss: 5.8813 - val_y2_output_mae: 1.6683
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 25.5536 - y1_output_loss: 11.7776 - y1_output_mae: 2.4889 - y2_output_loss: 13.0840 - y2_output_mae: 2.6061 - val_loss: 8.8197 - val_y1_output_loss: 3.4214 - val_y1_output_mae: 1.4182 - val_y2_output_loss: 5.5419 - val_y2_output_mae: 1.5872
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 25.8653 - y1_output_loss: 11.4635 - y1_output_mae: 2.4480 - y2_output_loss: 14.4222 - y2_output_mae: 2.8178 - val_loss: 8.3166 - val_y1_output_loss: 3.7886 - val_y1_output_mae: 1.4742 - val_y2_output_loss: 4.6071 - val_y2_output_mae: 1.5782
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 27.0576 - y1_output_loss: 11.3868 - y1_output_mae: 2.4559 - y2_output_loss: 15.1812 - y2_output_mae: 2.8045 - val_loss: 10.2472 - val_y1_output_loss: 4.3679 - val_y1_output_mae: 1.6443 - val_y2_output_loss: 6.0760 - val_y2_output_mae: 1.6971
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.4148 - y1_output_loss: 9.6238 - y1_output_mae: 2.3367 - y2_output_loss: 13.5171 - y2_output_mae: 2.6408 - val_loss: 10.7839 - val_y1_output_loss: 4.7593 - val_y1_output_mae: 1.6819 - val_y2_output_loss: 6.2276 - val_y2_output_mae: 1.6772
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 23.2162 - y1_output_loss: 11.3303 - y1_output_mae: 2.2851 - y2_output_loss: 13.2213 - y2_output_mae: 2.6273 - val_loss: 13.4949 - val_y1_output_loss: 6.1093 - val_y1_output_mae: 1.9711 - val_y2_output_loss: 7.5426 - val_y2_output_mae: 1.8894
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 22.6759 - y1_output_loss: 9.9779 - y1_output_mae: 2.2682 - y2_output_loss: 15.1539 - y2_output_mae: 2.5952 - val_loss: 13.6316 - val_y1_output_loss: 5.4382 - val_y1_output_mae: 1.8812 - val_y2_output_loss: 8.4447 - val_y2_output_mae: 2.0506
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 22.6400 - y1_output_loss: 10.9222 - y1_output_mae: 2.3577 - y2_output_loss: 11.6688 - y2_output_mae: 2.5134 - val_loss: 9.5833 - val_y1_output_loss: 4.1578 - val_y1_output_mae: 1.6208 - val_y2_output_loss: 5.5959 - val_y2_output_mae: 1.6353
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 24.8682 - y1_output_loss: 10.7783 - y1_output_mae: 2.4145 - y2_output_loss: 13.4103 - y2_output_mae: 2.6268 - val_loss: 8.2930 - val_y1_output_loss: 3.6836 - val_y1_output_mae: 1.4763 - val_y2_output_loss: 4.6893 - val_y2_output_mae: 1.5920
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.9090 - y1_output_loss: 10.3718 - y1_output_mae: 2.3489 - y2_output_loss: 10.2942 - y2_output_mae: 2.4257 - val_loss: 9.7673 - val_y1_output_loss: 4.5272 - val_y1_output_mae: 1.7315 - val_y2_output_loss: 5.4010 - val_y2_output_mae: 1.6315
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 22.2782 - y1_output_loss: 10.8295 - y1_output_mae: 2.3255 - y2_output_loss: 11.3368 - y2_output_mae: 2.4226 - val_loss: 9.0830 - val_y1_output_loss: 3.8171 - val_y1_output_mae: 1.5499 - val_y2_output_loss: 5.4386 - val_y2_output_mae: 1.6262
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.2745 - y1_output_loss: 8.8582 - y1_output_mae: 2.1482 - y2_output_loss: 11.0943 - y2_output_mae: 2.4308 - val_loss: 11.2348 - val_y1_output_loss: 5.6853 - val_y1_output_mae: 1.8669 - val_y2_output_loss: 5.7160 - val_y2_output_mae: 1.6101
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.7731 - y1_output_loss: 9.9975 - y1_output_mae: 2.2468 - y2_output_loss: 11.5095 - y2_output_mae: 2.4780 - val_loss: 12.1907 - val_y1_output_loss: 6.5726 - val_y1_output_mae: 2.0895 - val_y2_output_loss: 5.7954 - val_y2_output_mae: 1.6698
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 20.0588 - y1_output_loss: 9.7598 - y1_output_mae: 2.2780 - y2_output_loss: 10.0891 - y2_output_mae: 2.3606 - val_loss: 14.5693 - val_y1_output_loss: 5.6399 - val_y1_output_mae: 1.8499 - val_y2_output_loss: 9.2236 - val_y2_output_mae: 2.1275
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 20.7917 - y1_output_loss: 9.6237 - y1_output_mae: 2.2993 - y2_output_loss: 11.1533 - y2_output_mae: 2.4308 - val_loss: 14.7874 - val_y1_output_loss: 6.8762 - val_y1_output_mae: 2.0693 - val_y2_output_loss: 8.1653 - val_y2_output_mae: 1.9856
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 22.9786 - y1_output_loss: 11.2582 - y1_output_mae: 2.3921 - y2_output_loss: 12.0130 - y2_output_mae: 2.5303 - val_loss: 13.5445 - val_y1_output_loss: 5.0360 - val_y1_output_mae: 1.8086 - val_y2_output_loss: 8.7806 - val_y2_output_mae: 2.1457
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 21.8706 - y1_output_loss: 10.2295 - y1_output_mae: 2.2902 - y2_output_loss: 11.6756 - y2_output_mae: 2.4799 - val_loss: 6.1779 - val_y1_output_loss: 2.3483 - val_y1_output_mae: 1.1409 - val_y2_output_loss: 3.9049 - val_y2_output_mae: 1.4110
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 22.9238 - y1_output_loss: 9.7339 - y1_output_mae: 2.2436 - y2_output_loss: 14.0207 - y2_output_mae: 2.5139 - val_loss: 8.6042 - val_y1_output_loss: 4.6599 - val_y1_output_mae: 1.7557 - val_y2_output_loss: 4.0548 - val_y2_output_mae: 1.3937
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.8832 - y1_output_loss: 8.5658 - y1_output_mae: 2.1451 - y2_output_loss: 10.6972 - y2_output_mae: 2.3583 - val_loss: 10.4751 - val_y1_output_loss: 4.0281 - val_y1_output_mae: 1.5797 - val_y2_output_loss: 6.6511 - val_y2_output_mae: 1.7806
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 20.7794 - y1_output_loss: 9.8203 - y1_output_mae: 2.3007 - y2_output_loss: 10.8704 - y2_output_mae: 2.3920 - val_loss: 8.3979 - val_y1_output_loss: 4.0349 - val_y1_output_mae: 1.5032 - val_y2_output_loss: 4.4312 - val_y2_output_mae: 1.5014
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 21.6960 - y1_output_loss: 8.6565 - y1_output_mae: 2.1808 - y2_output_loss: 12.8370 - y2_output_mae: 2.5268 - val_loss: 8.5432 - val_y1_output_loss: 3.5079 - val_y1_output_mae: 1.5178 - val_y2_output_loss: 5.1728 - val_y2_output_mae: 1.5469
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 20.1676 - y1_output_loss: 9.1318 - y1_output_mae: 2.1774 - y2_output_loss: 11.1766 - y2_output_mae: 2.4160 - val_loss: 14.8464 - val_y1_output_loss: 7.5539 - val_y1_output_mae: 2.1252 - val_y2_output_loss: 7.5919 - val_y2_output_mae: 1.9034
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 20.1290 - y1_output_loss: 9.0371 - y1_output_mae: 2.1814 - y2_output_loss: 10.6871 - y2_output_mae: 2.3363 - val_loss: 9.1617 - val_y1_output_loss: 4.5931 - val_y1_output_mae: 1.6903 - val_y2_output_loss: 4.6888 - val_y2_output_mae: 1.4495
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 22.0079 - y1_output_loss: 10.0132 - y1_output_mae: 2.2675 - y2_output_loss: 12.4901 - y2_output_mae: 2.4919 - val_loss: 8.9700 - val_y1_output_loss: 3.4976 - val_y1_output_mae: 1.4897 - val_y2_output_loss: 5.6344 - val_y2_output_mae: 1.6085
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 19.8827 - y1_output_loss: 9.2818 - y1_output_mae: 2.1856 - y2_output_loss: 10.3756 - y2_output_mae: 2.3347 - val_loss: 7.8325 - val_y1_output_loss: 4.0600 - val_y1_output_mae: 1.5240 - val_y2_output_loss: 3.9130 - val_y2_output_mae: 1.3847
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 19.5820 - y1_output_loss: 9.6203 - y1_output_mae: 2.2272 - y2_output_loss: 9.5091 - y2_output_mae: 2.3253 - val_loss: 8.0691 - val_y1_output_loss: 3.1485 - val_y1_output_mae: 1.3275 - val_y2_output_loss: 5.0719 - val_y2_output_mae: 1.5332
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 22.4943 - y1_output_loss: 9.1902 - y1_output_mae: 2.2394 - y2_output_loss: 12.4878 - y2_output_mae: 2.5820 - val_loss: 10.9438 - val_y1_output_loss: 7.0541 - val_y1_output_mae: 2.0990 - val_y2_output_loss: 4.1056 - val_y2_output_mae: 1.3799
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 20.7294 - y1_output_loss: 9.8992 - y1_output_mae: 2.1848 - y2_output_loss: 11.0805 - y2_output_mae: 2.4466 - val_loss: 8.7495 - val_y1_output_loss: 3.5015 - val_y1_output_mae: 1.5316 - val_y2_output_loss: 5.4242 - val_y2_output_mae: 1.5824
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 18.4137 - y1_output_loss: 7.7013 - y1_output_mae: 2.0230 - y2_output_loss: 10.1006 - y2_output_mae: 2.3269 - val_loss: 9.9644 - val_y1_output_loss: 4.4120 - val_y1_output_mae: 1.5954 - val_y2_output_loss: 5.7370 - val_y2_output_mae: 1.5987
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 18.0399 - y1_output_loss: 8.9626 - y1_output_mae: 2.0868 - y2_output_loss: 9.2356 - y2_output_mae: 2.1634 - val_loss: 11.1261 - val_y1_output_loss: 5.7128 - val_y1_output_mae: 1.8778 - val_y2_output_loss: 5.5907 - val_y2_output_mae: 1.6209
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 20.2942 - y1_output_loss: 7.9583 - y1_output_mae: 2.0366 - y2_output_loss: 12.0980 - y2_output_mae: 2.4951 - val_loss: 10.1765 - val_y1_output_loss: 5.1981 - val_y1_output_mae: 1.8457 - val_y2_output_loss: 5.1746 - val_y2_output_mae: 1.5916
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 17.0148 - y1_output_loss: 8.2850 - y1_output_mae: 2.0828 - y2_output_loss: 8.3737 - y2_output_mae: 2.1353 - val_loss: 5.5543 - val_y1_output_loss: 2.3938 - val_y1_output_mae: 1.2119 - val_y2_output_loss: 3.2639 - val_y2_output_mae: 1.3098
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 19.0579 - y1_output_loss: 8.9225 - y1_output_mae: 2.1913 - y2_output_loss: 9.6382 - y2_output_mae: 2.2999 - val_loss: 8.1826 - val_y1_output_loss: 2.7432 - val_y1_output_mae: 1.2789 - val_y2_output_loss: 5.6011 - val_y2_output_mae: 1.5651
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.3679 - y1_output_loss: 8.0734 - y1_output_mae: 2.0576 - y2_output_loss: 11.6522 - y2_output_mae: 2.4238 - val_loss: 8.6394 - val_y1_output_loss: 4.1959 - val_y1_output_mae: 1.5646 - val_y2_output_loss: 4.6230 - val_y2_output_mae: 1.4359
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 17.3055 - y1_output_loss: 7.8630 - y1_output_mae: 2.0622 - y2_output_loss: 8.9768 - y2_output_mae: 2.1955 - val_loss: 10.7561 - val_y1_output_loss: 4.4839 - val_y1_output_mae: 1.6348 - val_y2_output_loss: 6.5195 - val_y2_output_mae: 1.7703
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 18.0323 - y1_output_loss: 7.8468 - y1_output_mae: 2.0213 - y2_output_loss: 10.0359 - y2_output_mae: 2.2714 - val_loss: 11.3464 - val_y1_output_loss: 5.2105 - val_y1_output_mae: 1.7294 - val_y2_output_loss: 6.3605 - val_y2_output_mae: 1.6991
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 18.2604 - y1_output_loss: 8.8042 - y1_output_mae: 2.1376 - y2_output_loss: 9.0624 - y2_output_mae: 2.2331 - val_loss: 12.2049 - val_y1_output_loss: 5.9824 - val_y1_output_mae: 1.9047 - val_y2_output_loss: 6.4370 - val_y2_output_mae: 1.7381
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.6623 - y1_output_loss: 7.1508 - y1_output_mae: 1.9485 - y2_output_loss: 10.8713 - y2_output_mae: 2.2623 - val_loss: 14.4898 - val_y1_output_loss: 8.0958 - val_y1_output_mae: 2.1570 - val_y2_output_loss: 6.6241 - val_y2_output_mae: 1.7042
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 16.3854 - y1_output_loss: 6.8857 - y1_output_mae: 1.9005 - y2_output_loss: 10.3129 - y2_output_mae: 2.2810 - val_loss: 10.4884 - val_y1_output_loss: 4.4974 - val_y1_output_mae: 1.6246 - val_y2_output_loss: 6.1936 - val_y2_output_mae: 1.6485
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 16.7003 - y1_output_loss: 6.9090 - y1_output_mae: 1.9111 - y2_output_loss: 9.8697 - y2_output_mae: 2.2650 - val_loss: 10.3657 - val_y1_output_loss: 6.1229 - val_y1_output_mae: 1.9629 - val_y2_output_loss: 4.4289 - val_y2_output_mae: 1.4311
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 17.7153 - y1_output_loss: 7.3178 - y1_output_mae: 1.9747 - y2_output_loss: 10.3156 - y2_output_mae: 2.3265 - val_loss: 6.1076 - val_y1_output_loss: 2.4257 - val_y1_output_mae: 1.1823 - val_y2_output_loss: 3.7733 - val_y2_output_mae: 1.3581
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.5653 - y1_output_loss: 8.6173 - y1_output_mae: 2.0931 - y2_output_loss: 10.3215 - y2_output_mae: 2.3249 - val_loss: 9.7631 - val_y1_output_loss: 4.9328 - val_y1_output_mae: 1.6802 - val_y2_output_loss: 4.9975 - val_y2_output_mae: 1.5252
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.8823 - y1_output_loss: 7.6992 - y1_output_mae: 2.0608 - y2_output_loss: 9.8205 - y2_output_mae: 2.1988 - val_loss: 9.4241 - val_y1_output_loss: 5.6294 - val_y1_output_mae: 1.8495 - val_y2_output_loss: 3.9523 - val_y2_output_mae: 1.3767
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 17.7120 - y1_output_loss: 7.8984 - y1_output_mae: 1.9875 - y2_output_loss: 9.9303 - y2_output_mae: 2.2184 - val_loss: 9.8470 - val_y1_output_loss: 4.6377 - val_y1_output_mae: 1.6531 - val_y2_output_loss: 5.4114 - val_y2_output_mae: 1.5931
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.3579 - y1_output_loss: 7.6190 - y1_output_mae: 1.9508 - y2_output_loss: 9.1124 - y2_output_mae: 2.1677 - val_loss: 13.3174 - val_y1_output_loss: 7.9160 - val_y1_output_mae: 2.2178 - val_y2_output_loss: 5.6150 - val_y2_output_mae: 1.6506
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 16.8082 - y1_output_loss: 7.2985 - y1_output_mae: 1.9211 - y2_output_loss: 9.1100 - y2_output_mae: 2.1994 - val_loss: 8.5351 - val_y1_output_loss: 4.8951 - val_y1_output_mae: 1.7234 - val_y2_output_loss: 3.7734 - val_y2_output_mae: 1.3153
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 16.9856 - y1_output_loss: 7.0785 - y1_output_mae: 1.9421 - y2_output_loss: 10.0077 - y2_output_mae: 2.1855 - val_loss: 9.4829 - val_y1_output_loss: 4.5608 - val_y1_output_mae: 1.6293 - val_y2_output_loss: 5.0945 - val_y2_output_mae: 1.5196
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 15.2434 - y1_output_loss: 6.4374 - y1_output_mae: 1.8570 - y2_output_loss: 8.6188 - y2_output_mae: 2.0963 - val_loss: 14.7867 - val_y1_output_loss: 6.9076 - val_y1_output_mae: 2.0339 - val_y2_output_loss: 8.2262 - val_y2_output_mae: 2.0184
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 16.3578 - y1_output_loss: 8.0683 - y1_output_mae: 1.9601 - y2_output_loss: 8.4712 - y2_output_mae: 2.0718 - val_loss: 11.9855 - val_y1_output_loss: 6.9900 - val_y1_output_mae: 2.0550 - val_y2_output_loss: 5.2096 - val_y2_output_mae: 1.5440
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 17.0442 - y1_output_loss: 8.0153 - y1_output_mae: 1.9264 - y2_output_loss: 8.8186 - y2_output_mae: 2.1961 - val_loss: 8.3328 - val_y1_output_loss: 4.3725 - val_y1_output_mae: 1.5709 - val_y2_output_loss: 4.1451 - val_y2_output_mae: 1.3911
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 15.3293 - y1_output_loss: 6.6435 - y1_output_mae: 1.8055 - y2_output_loss: 8.3175 - y2_output_mae: 2.1344 - val_loss: 9.6164 - val_y1_output_loss: 5.2817 - val_y1_output_mae: 1.7225 - val_y2_output_loss: 4.5168 - val_y2_output_mae: 1.4203
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.4423 - y1_output_loss: 7.0312 - y1_output_mae: 1.8772 - y2_output_loss: 9.9290 - y2_output_mae: 2.2694 - val_loss: 12.8446 - val_y1_output_loss: 6.7452 - val_y1_output_mae: 2.0054 - val_y2_output_loss: 6.3010 - val_y2_output_mae: 1.7414
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.9524 - y1_output_loss: 7.7623 - y1_output_mae: 1.9551 - y2_output_loss: 9.9280 - y2_output_mae: 2.2916 - val_loss: 18.2308 - val_y1_output_loss: 8.3946 - val_y1_output_mae: 2.2231 - val_y2_output_loss: 10.1464 - val_y2_output_mae: 2.2981
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.2689 - y1_output_loss: 6.9840 - y1_output_mae: 1.9260 - y2_output_loss: 10.2183 - y2_output_mae: 2.2521 - val_loss: 18.7726 - val_y1_output_loss: 10.3964 - val_y1_output_mae: 2.4680 - val_y2_output_loss: 8.7561 - val_y2_output_mae: 2.0737
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.5380 - y1_output_loss: 7.2384 - y1_output_mae: 1.8895 - y2_output_loss: 10.2681 - y2_output_mae: 2.3013 - val_loss: 6.2451 - val_y1_output_loss: 2.1938 - val_y1_output_mae: 1.1717 - val_y2_output_loss: 4.1562 - val_y2_output_mae: 1.4400
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 16.0729 - y1_output_loss: 6.8216 - y1_output_mae: 1.8657 - y2_output_loss: 9.0620 - y2_output_mae: 2.1833 - val_loss: 6.2384 - val_y1_output_loss: 3.1179 - val_y1_output_mae: 1.3358 - val_y2_output_loss: 3.2125 - val_y2_output_mae: 1.2815
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.8762 - y1_output_loss: 7.0915 - y1_output_mae: 1.9298 - y2_output_loss: 9.5956 - y2_output_mae: 2.1602 - val_loss: 7.5530 - val_y1_output_loss: 3.6098 - val_y1_output_mae: 1.4303 - val_y2_output_loss: 4.1284 - val_y2_output_mae: 1.4062

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Evaluamos el modelo
results = model.evaluate(X_test, [y1_test, y2_test], verbose=0)

test_loss, y1_loss, y2_loss, test_mae_heating, test_mae_cooling = results

print(f"Total Test Loss: {test_loss:.4f}")
print(f"Heating Loss: {y1_loss:.4f}, Cooling Loss: {y2_loss:.4f}")
print(f"Test MAE for Heating Load: {test_mae_heating:.4f} Wh")
print(f"Test MAE for Cooling Load: {test_mae_cooling:.4f} Wh")
# Out:
# Total Test Loss: 7.5530
# Heating Loss: 3.6098, Cooling Loss: 4.1284
# Test MAE for Heating Load: 1.4303 Wh
# Test MAE for Cooling Load: 1.4062 Wh

# %%
import matplotlib.pyplot as plt


print(history.history.keys())

# ---- Graficamos el loss, que en este caso decidimos que fuera el MSE
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Total Training Loss')
plt.plot(history.history['val_loss'], label='Total Validation Loss')
plt.plot(history.history['y1_output_loss'], label='Heating Training Loss')
plt.plot(history.history['val_y1_output_loss'], label='Heating Validation Loss')
plt.plot(history.history['y2_output_loss'], label='Cooling Training Loss')
plt.plot(history.history['val_y2_output_loss'], label='Cooling Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# Graficamos el MAE
plt.figure(figsize=(10, 6))
plt.plot(history.history['y1_output_mae'], label='Heating Training MAE')
plt.plot(history.history['val_y1_output_mae'], label='Heating Validation MAE')
plt.plot(history.history['y2_output_mae'], label='Cooling Training MAE')
plt.plot(history.history['val_y2_output_mae'], label='Cooling Validation MAE')
plt.title('Model MAE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE (Wh)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Realizar predicciones
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

#Como tenemos dos targets, las predicciones hay que separarlas
y_train_pred_heating = y_pred_train[0].flatten()
y_train_pred_cooling = y_pred_train[1].flatten()

y_test_pred_heating = y_pred_test[0].flatten()
y_test_pred_cooling = y_pred_test[1].flatten()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
#Metricas de performance para heating

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

def regression_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(root_mean_squared_error(y_true, y_pred))
    return r2, mae, rmse

# Metricas train
r2_train_heat, mae_train_heat, rmse_train_heat = regression_metrics(y1_train, y_train_pred_heating)
r2_train_cool, mae_train_cool, rmse_train_cool = regression_metrics(y2_train, y_train_pred_cooling)
print("=== Train Performance ===")
print(f"Heating Load: R²={r2_train_heat:.3f}, MAE={mae_train_heat:.3f}, RMSE={rmse_train_heat:.3f}")
print(f"Cooling Load: R²={r2_train_cool:.3f}, MAE={mae_train_cool:.3f}, RMSE={rmse_train_cool:.3f}")

# metricas test
r2_test_heat, mae_test_heat, rmse_test_heat = regression_metrics(y1_test, y_test_pred_heating)
r2_test_cool, mae_test_cool, rmse_test_cool = regression_metrics(y2_test, y_test_pred_cooling)
print("\n=== Test Performance ===")
print(f"Heating Load: R²={r2_test_heat:.3f}, MAE={mae_test_heat:.3f}, RMSE={rmse_test_heat:.3f}")
print(f"Cooling Load: R²={r2_test_cool:.3f}, MAE={mae_test_cool:.3f}, RMSE={rmse_test_cool:.3f}")
# Out:
# === Train Performance ===
# Heating Load: R²=0.970, MAE=1.302, RMSE=1.314
# Cooling Load: R²=0.965, MAE=1.200, RMSE=1.330
#
# === Test Performance ===
# Heating Load: R²=0.966, MAE=1.430, RMSE=1.373
# Cooling Load: R²=0.957, MAE=1.406, RMSE=1.414

# %% [markdown]
# #### Cross Validation

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models

def build_model(input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # Capas compartidas
    x = layers.Dense(128, activation='relu')(input_layer)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    
    # Heating
    h = layers.Dense(64, activation='relu')(x)
    h = layers.Dropout(0.2)(h)
    h = layers.Dense(32, activation='relu')(h)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling
    c = layers.Dense(64, activation='relu')(x)
    c = layers.Dropout(0.2)(c)
    c = layers.Dense(32, activation='relu')(c)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
from sklearn.model_selection import KFold

from sklearn.preprocessing import StandardScaler
from numpy import sqrt

#KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

r2_heat, r2_cool = [], []
mae_heat, mae_cool = [], []
rmse_heat, rmse_cool = [], []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n Fold {fold+1}")
    
    # Split data
    X_train, X_val = X[train_idx], X[val_idx]
    y_train_heat, y_val_heat = df['Y1'][train_idx], df['Y1'][val_idx]
    y_train_cool, y_val_cool = df['Y2'][train_idx], df['Y2'][val_idx]
    
    # Scale inputs
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    
    # Build & train model
    model = build_model(X.shape[1])
    model.fit(
        X_train, [y_train_heat, y_train_cool],
        epochs=80, batch_size=32, verbose=0
    )
    
    # Predict
    y_pred_heat, y_pred_cool = model.predict(X_val, verbose=0)
    
    # Flatten
    y_pred_heat, y_pred_cool = y_pred_heat.flatten(), y_pred_cool.flatten()
    
    # Compute metrics
    r2_heat.append(r2_score(y_val_heat, y_pred_heat))
    r2_cool.append(r2_score(y_val_cool, y_pred_cool))
    mae_heat.append(mean_absolute_error(y_val_heat, y_pred_heat))
    mae_cool.append(mean_absolute_error(y_val_cool, y_pred_cool))
    rmse_heat.append(sqrt(mean_squared_error(y_val_heat, y_pred_heat)))
    rmse_cool.append(sqrt(mean_squared_error(y_val_cool, y_pred_cool)))
# Out:
#  Fold 1
#
#  Fold 2
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000175103040E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 3
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001750B8023E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 4
#
#  Fold 5

# %%
print("\n=== Cross-Validation Results ===")
print(f"Heating Load: R2={np.mean(r2_heat):.3f}±{np.std(r2_heat):.3f}, "
      f"MAE={np.mean(mae_heat):.3f}, RMSE={np.mean(rmse_heat):.3f}")
print(f"Cooling Load: R2={np.mean(r2_cool):.3f}±{np.std(r2_cool):.3f}, "
      f"MAE={np.mean(mae_cool):.3f}, RMSE={np.mean(rmse_cool):.3f}")
# Out:
# === Cross-Validation Results ===
# Heating Load: R2=0.950±0.011, MAE=1.725, RMSE=2.234
# Cooling Load: R2=0.938±0.002, MAE=1.652, RMSE=2.348

# %% [markdown]
# ## Tuneo de hiperparametros
#
# Especificamente diseniado para redes neuronales

# %%
# Random Serach
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers

df = pd.read_csv("ENB2012_data.csv")
X_full = df[['X1','X2','X3','X4','X5','X6','X7','X8']].values
y1_full = df['Y1'].values
y2_full = df['Y2'].values

scaler = StandardScaler()
X_full = scaler.fit_transform(X_full)


X_train_full, X_test_full, y1_train_full, y1_test_full, y2_train_full, y2_test_full = train_test_split(
    X_full, y1_full, y2_full, test_size=0.2, random_state=42
)


# Definimos el contructor del modelo

def build_random_model(params, input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # compartidas
    x = input_layer
    for i in range(params['n_shared_layers']):
        x = layers.Dense(params['n_shared_units'], activation='relu')(x)
        x = layers.Dropout(params['dropout_rate'])(x)
    
    # Heating 
    h = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling 
    c = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    
    opt = optimizers.Adam(learning_rate=params['learning_rate'])
    model.compile(
        optimizer=opt,
        loss={'heating_output': 'mse', 'cooling_output': 'mse'},
        metrics={'heating_output': 'mae', 'cooling_output': 'mae'}
    )
    
    return model


# Espacio para el random search

param_distributions = {
    'n_shared_layers': [1, 2, 3],
    'n_shared_units': [32, 64, 128, 256],
    'dropout_rate': [0.0, 0.1, 0.2, 0.3, 0.4],
    'learning_rate': [1e-4, 5e-4, 1e-3, 5e-3],
    'batch_size': [16, 32, 64]
}


n_trials = 5
results = []

print("\n Empezamos Random Search")
for i in range(n_trials):
    params = {k: random.choice(v) for k, v in param_distributions.items()}
    print(f"\nTrial {i+1}/{n_trials} with params: {params}")
    
    X_train_rs, X_val_rs, y1_train_rs, y1_val_rs, y2_train_rs, y2_val_rs = train_test_split(
        X_train_full, y1_train_full, y2_train_full, test_size=0.2, random_state=i
    )
    
    model = build_random_model(params, X_train_rs.shape[1])
    history = model.fit(
        X_train_rs, [y1_train_rs, y2_train_rs],
        validation_data=(X_val_rs, [y1_val_rs, y2_val_rs]),
        epochs=50, batch_size=params['batch_size'], verbose=0
    )
    
    val_loss = np.mean(history.history['val_loss'][-5:])
    results.append((params, val_loss))
    print(f"Validation Loss: {val_loss:.4f}")

# Resultados
results.sort(key=lambda x: x[1])
print("\n Results")
for rank, (params, loss) in enumerate(results, 1):
    print(f"{rank:2d}) Val Loss={loss:.4f} | Params={params}")

best_params, best_loss = results[0]
print("\n Mejor configuracion:")
print(best_params)
print(f"Validation Loss: {best_loss:.4f}")
# Out:
#  Empezamos Random Search
#
# Trial 1/5 with params: {'n_shared_layers': 2, 'n_shared_units': 128, 'dropout_rate': 0.1, 'learning_rate': 0.001, 'batch_size': 32}
# Validation Loss: 15.7656
#
# Trial 2/5 with params: {'n_shared_layers': 1, 'n_shared_units': 64, 'dropout_rate': 0.1, 'learning_rate': 0.001, 'batch_size': 64}
# Validation Loss: 35.8631
#
# Trial 3/5 with params: {'n_shared_layers': 3, 'n_shared_units': 256, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'batch_size': 16}
# Validation Loss: 16.9035
#
# Trial 4/5 with params: {'n_shared_layers': 2, 'n_shared_units': 64, 'dropout_rate': 0.3, 'learning_rate': 0.0005, 'batch_size': 16}
# Validation Loss: 17.5105
#
# Trial 5/5 with params: {'n_shared_layers': 1, 'n_shared_units': 256, 'dropout_rate': 0.1, 'learning_rate': 0.005, 'batch_size': 64}
# Validation Loss: 18.6979
#
#  Results
#  1) Val Loss=15.7656 | Params={'n_shared_layers': 2, 'n_shared_units': 128, 'dropout_rate': 0.1, 'learning_rate': 0.001, 'batch_size': 32}
#  2) Val Loss=16.9035 | Params={'n_shared_layers': 3, 'n_shared_units': 256, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'batch_size': 16}
#  3) Val Loss=17.5105 | Params={'n_shared_layers': 2, 'n_shared_units': 64, 'dropout_rate': 0.3, 'learning_rate': 0.0005, 'batch_size': 16}
#  4) Val Loss=18.6979 | Params={'n_shared_layers': 1, 'n_shared_units': 256, 'dropout_rate': 0.1, 'learning_rate': 0.005, 'batch_size': 64}
#  5) Val Loss=35.8631 | Params={'n_shared_layers': 1, 'n_shared_units': 64, 'dropout_rate': 0.1, 'learning_rate': 0.001, 'batch_size': 64}
#
#  Mejor configuracion:
# {'n_shared_layers': 2, 'n_shared_units': 128, 'dropout_rate': 0.1, 'learning_rate': 0.001, 'batch_size': 32}
# Validation Loss: 15.7656

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
